# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
pd.set_option("display.float_format", "{:.2f}".format)

# %%
data=pd.read_csv('Churn_Modelling_Practice_Corrupted.csv')

# %%
data
# Out:
#        RowNumber  CustomerId   Surname  CreditScore Geography  Gender    Age  \
# 0              1    15634602  Hargrave       619.00    France  Female  42.00
# 1              2    15647311      Hill       608.00     Spain  Female  41.00
# 2              3    15619304      Onio       502.00    France  Female  42.00
# 3              4    15701354      Boni       699.00    France  Female  39.00
# 4              5    15737888  Mitchell       850.00     Spain  Female  43.00
# ...          ...         ...       ...          ...       ...     ...    ...
# 10006        801    15747542     Perez       605.00   France     Male  52.00
# 10007        901    15642041     Burns       727.00   Germany    male  40.00
# 10008       1501    15590146       Mao       630.00    France    Male 150.00
# 10009       1701    15642833  Akubundu       608.00    France  Female  30.00
# 10010       2001    15613656  Lombardi       842.00    Spain   FEMALE 200.00
#
# ...

# %%
df=data.copy()

# %%
df
# Out:
#        RowNumber  CustomerId   Surname  CreditScore Geography  Gender    Age  \
# 0              1    15634602  Hargrave       619.00    France  Female  42.00
# 1              2    15647311      Hill       608.00     Spain  Female  41.00
# 2              3    15619304      Onio       502.00    France  Female  42.00
# 3              4    15701354      Boni       699.00    France  Female  39.00
# 4              5    15737888  Mitchell       850.00     Spain  Female  43.00
# ...          ...         ...       ...          ...       ...     ...    ...
# 10006        801    15747542     Perez       605.00   France     Male  52.00
# 10007        901    15642041     Burns       727.00   Germany    male  40.00
# 10008       1501    15590146       Mao       630.00    France    Male 150.00
# 10009       1701    15642833  Akubundu       608.00    France  Female  30.00
# 10010       2001    15613656  Lombardi       842.00    Spain   FEMALE 200.00
#
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave       619.00    France  Female 42.00
# 1          2    15647311      Hill       608.00     Spain  Female 41.00
# 2          3    15619304      Onio       502.00    France  Female 42.00
# 3          4    15701354      Boni       699.00    France  Female 39.00
# 4          5    15737888  Mitchell       850.00     Spain  Female 43.00
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
# 2       8 159660.80              3          1               0
# 3       1      0.00              2          0               0
# 4       2 125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10011, 14)

# %%
df.describe()
# Out:
#        RowNumber  CustomerId  CreditScore      Age   Tenure   Balance  \
# count   10011.00    10011.00     10010.00 10010.00 10011.00  10011.00
# mean     4996.95 15690911.07       650.56    38.96     5.01  76454.24
# std      2888.65    71973.82        96.65    10.72     2.89  62383.59
# min         1.00 15453562.00       350.00    18.00    -2.00      0.00
# 25%      2493.50 15628471.50       584.00    32.00     3.00      0.00
# 50%      4996.00 15690695.00       652.00    37.00     5.00  97086.40
# 75%      7498.50 15753222.00       718.00    44.00     7.00 127634.77
# max     10001.00 15815690.00       850.00   200.00    10.00 250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10011.00   10011.00        10011.00         10011.00 10011.00
# mean            1.53       0.71            0.52        100106.14     0.20
# std             0.58       0.46            0.50         57499.52     0.40
# ...

# %%
df
# Out:
#        RowNumber  CustomerId   Surname  CreditScore Geography  Gender    Age  \
# 0              1    15634602  Hargrave       619.00    France  Female  42.00
# 1              2    15647311      Hill       608.00     Spain  Female  41.00
# 2              3    15619304      Onio       502.00    France  Female  42.00
# 3              4    15701354      Boni       699.00    France  Female  39.00
# 4              5    15737888  Mitchell       850.00     Spain  Female  43.00
# ...          ...         ...       ...          ...       ...     ...    ...
# 10006        801    15747542     Perez       605.00   France     Male  52.00
# 10007        901    15642041     Burns       727.00   Germany    male  40.00
# 10008       1501    15590146       Mao       630.00    France    Male 150.00
# 10009       1701    15642833  Akubundu       608.00    France  Female  30.00
# 10010       2001    15613656  Lombardi       842.00    Spain   FEMALE 200.00
#
# ...

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        1
# Geography          1
# Gender             0
# Age                1
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#        RowNumber  CustomerId Surname  CreditScore Geography  Gender   Age  \
# 10001        101    15808582      Fu       665.00    France  Female   NaN
# 10002        251    15628112  Hughes       771.00       NaN  Female 36.00
# 10003        401    15690452    Tung          NaN    France    Male 52.00
#
#        Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 10001       6     0.00              1          1               1
# 10002       5 77846.90              1          0               0
# 10003       1 63349.75              1          1               0
#
#        EstimatedSalary  Exited
# 10001        161848.03       0
# 10002         99805.99       0
# 10003        108887.44       0

# %%
df[df.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df.dropna(how='any',inplace=True)

# %%
df
# Out:
#        RowNumber  CustomerId   Surname  CreditScore Geography  Gender    Age  \
# 0              1    15634602  Hargrave       619.00    France  Female  42.00
# 1              2    15647311      Hill       608.00     Spain  Female  41.00
# 2              3    15619304      Onio       502.00    France  Female  42.00
# 3              4    15701354      Boni       699.00    France  Female  39.00
# 4              5    15737888  Mitchell       850.00     Spain  Female  43.00
# ...          ...         ...       ...          ...       ...     ...    ...
# 10006        801    15747542     Perez       605.00   France     Male  52.00
# 10007        901    15642041     Burns       727.00   Germany    male  40.00
# 10008       1501    15590146       Mao       630.00    France    Male 150.00
# 10009       1701    15642833  Akubundu       608.00    France  Female  30.00
# 10010       2001    15613656  Lombardi       842.00    Spain   FEMALE 200.00
#
# ...

# %%
df.isna().sum()*100/len(df)
# Out:
# RowNumber         0.00
# CustomerId        0.00
# Surname           0.00
# CreditScore       0.00
# Geography         0.00
# Gender            0.00
# Age               0.00
# Tenure            0.00
# Balance           0.00
# NumOfProducts     0.00
# HasCrCard         0.00
# IsActiveMember    0.00
# EstimatedSalary   0.00
# Exited            0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df[df.duplicated()] # first occurence in the data false , duplicates = True
# Out:
#        RowNumber  CustomerId Surname  CreditScore Geography  Gender   Age  \
# 10004        601    15683503  Hudson       601.00    France  Female 43.00
# 10005       1201    15804602    Boyd       772.00   Germany    Male 30.00
#
#        Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 10004       8     0.00              3          0               1
# 10005       6 99785.28              2          0               0
#
#        EstimatedSalary  Exited
# 10004        110916.15       1
# 10005        197238.03       0

# %%
df.query(' RowNumber == [601,1201]')
# Out:
#        RowNumber  CustomerId Surname  CreditScore Geography  Gender   Age  \
# 600          601    15683503  Hudson       601.00    France  Female 43.00
# 1200        1201    15804602    Boyd       772.00   Germany    Male 30.00
# 10004        601    15683503  Hudson       601.00    France  Female 43.00
# 10005       1201    15804602    Boyd       772.00   Germany    Male 30.00
#
#        Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 600         8     0.00              3          0               1
# 1200        6 99785.28              2          0               0
# 10004       8     0.00              3          0               1
# 10005       6 99785.28              2          0               0
#
#        EstimatedSalary  Exited
# 600          110916.15       1
# 1200         197238.03       0
# 10004        110916.15       1
# 10005        197238.03       0

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Age'].describe()
# Out:
# count   10006.00
# mean       38.96
# std        10.72
# min        18.00
# 25%        32.00
# 50%        37.00
# 75%        44.00
# max       200.00
# Name: Age, dtype: float64

# %%
df.query('Age > 95')
# Out:
#        RowNumber  CustomerId   Surname  CreditScore Geography  Gender    Age  \
# 10000      10001    15453562   Spiners       643.00     Spain  Female 150.00
# 10008       1501    15590146       Mao       630.00    France    Male 150.00
# 10010       2001    15613656  Lombardi       842.00    Spain   FEMALE 200.00
#
#        Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 10000       3 45000.65              1          1               1
# 10008       1 81947.76              1          0               1
# 10010       1 63492.94              1          1               1
#
#        EstimatedSalary  Exited
# 10000         60000.00       1
# 10008         63606.22       1
# 10010         83172.19       0

# %%
df[df['Age']<95]
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave       619.00    France  Female 42.00
# 1              2    15647311       Hill       608.00     Spain  Female 41.00
# 2              3    15619304       Onio       502.00    France  Female 42.00
# 3              4    15701354       Boni       699.00    France  Female 39.00
# 4              5    15737888   Mitchell       850.00     Spain  Female 43.00
# ...          ...         ...        ...          ...       ...     ...   ...
# 9998        9999    15682355  Sabbatini       772.00   Germany    Male 42.00
# 9999       10000    15628319     Walker       792.00    France  Female 28.00
# 10006        801    15747542      Perez       605.00   France     Male 52.00
# 10007        901    15642041      Burns       727.00   Germany    male 40.00
# 10009       1701    15642833   Akubundu       608.00    France  Female 30.00
#
# ...

# %%
df=df[df['Age']<95]

# %%
df
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave       619.00    France  Female 42.00
# 1              2    15647311       Hill       608.00     Spain  Female 41.00
# 2              3    15619304       Onio       502.00    France  Female 42.00
# 3              4    15701354       Boni       699.00    France  Female 39.00
# 4              5    15737888   Mitchell       850.00     Spain  Female 43.00
# ...          ...         ...        ...          ...       ...     ...   ...
# 9998        9999    15682355  Sabbatini       772.00   Germany    Male 42.00
# 9999       10000    15628319     Walker       792.00    France  Female 28.00
# 10006        801    15747542      Perez       605.00   France     Male 52.00
# 10007        901    15642041      Burns       727.00   Germany    male 40.00
# 10009       1701    15642833   Akubundu       608.00    France  Female 30.00
#
# ...

# %%
df['Age'].describe()
# Out:
# count   10003.00
# mean       38.92
# std        10.49
# min        18.00
# 25%        32.00
# 50%        37.00
# 75%        44.00
# max        92.00
# Name: Age, dtype: float64

# %%
df.describe()
# Out:
#        RowNumber  CustomerId  CreditScore      Age   Tenure   Balance  \
# count   10003.00    10003.00     10003.00 10003.00 10003.00  10003.00
# mean     4999.34 15690936.53       650.53    38.92     5.01  76472.25
# std      2887.25    71930.89        96.64    10.49     2.89  62397.64
# min         1.00 15565701.00       350.00    18.00    -2.00      0.00
# 25%      2498.50 15628544.00       584.00    32.00     3.00      0.00
# 50%      4999.00 15690733.00       652.00    37.00     5.00  97157.96
# 75%      7499.50 15753222.00       718.00    44.00     7.00 127640.40
# max     10000.00 15815690.00       850.00    92.00    10.00 250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10003.00   10003.00        10003.00         10003.00 10003.00
# mean            1.53       0.71            0.52        100097.68     0.20
# std             0.58       0.46            0.50         57508.02     0.40
# ...

# %%
df['Tenure'].describe()
# Out:
# count   10003.00
# mean        5.01
# std         2.89
# min        -2.00
# 25%         3.00
# 50%         5.00
# 75%         7.00
# max        10.00
# Name: Tenure, dtype: float64

# %%
df.query('Tenure <0')
# Out:
#        RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 10009       1701    15642833  Akubundu       608.00    France  Female 30.00
#
#        Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 10009      -2     0.00              2          1               0
#
#        EstimatedSalary  Exited
# 10009        128875.86       0

# %%
df[df['Tenure']>=0]
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave       619.00    France  Female 42.00
# 1              2    15647311       Hill       608.00     Spain  Female 41.00
# 2              3    15619304       Onio       502.00    France  Female 42.00
# 3              4    15701354       Boni       699.00    France  Female 39.00
# 4              5    15737888   Mitchell       850.00     Spain  Female 43.00
# ...          ...         ...        ...          ...       ...     ...   ...
# 9997        9998    15584532        Liu       709.00    France  Female 36.00
# 9998        9999    15682355  Sabbatini       772.00   Germany    Male 42.00
# 9999       10000    15628319     Walker       792.00    France  Female 28.00
# 10006        801    15747542      Perez       605.00   France     Male 52.00
# 10007        901    15642041      Burns       727.00   Germany    male 40.00
#
# ...

# %%
df=df[df['Tenure']>=0]

# %%
df
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave       619.00    France  Female 42.00
# 1              2    15647311       Hill       608.00     Spain  Female 41.00
# 2              3    15619304       Onio       502.00    France  Female 42.00
# 3              4    15701354       Boni       699.00    France  Female 39.00
# 4              5    15737888   Mitchell       850.00     Spain  Female 43.00
# ...          ...         ...        ...          ...       ...     ...   ...
# 9997        9998    15584532        Liu       709.00    France  Female 36.00
# 9998        9999    15682355  Sabbatini       772.00   Germany    Male 42.00
# 9999       10000    15628319     Walker       792.00    France  Female 28.00
# 10006        801    15747542      Perez       605.00   France     Male 52.00
# 10007        901    15642041      Burns       727.00   Germany    male 40.00
#
# ...

# %%
df.describe()
# Out:
#        RowNumber  CustomerId  CreditScore      Age   Tenure   Balance  \
# count   10002.00    10002.00     10002.00 10002.00 10002.00  10002.00
# mean     4999.67 15690941.34       650.53    38.92     5.01  76479.90
# std      2887.20    71932.88        96.65    10.49     2.89  62396.07
# min         1.00 15565701.00       350.00    18.00     0.00      0.00
# 25%      2499.25 15628537.00       584.00    32.00     3.00      0.00
# 50%      4999.50 15690738.00       652.00    37.00     5.00  97173.29
# 75%      7499.75 15753225.50       718.00    44.00     7.00 127641.42
# max     10000.00 15815690.00       850.00    92.00    10.00 250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10002.00   10002.00        10002.00         10002.00 10002.00
# mean            1.53       0.71            0.52        100094.80     0.20
# std             0.58       0.46            0.50         57510.18     0.40
# ...

# %%
df.query('Balance==999999999.00')
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df.describe()
# Out:
#        RowNumber  CustomerId  CreditScore      Age   Tenure   Balance  \
# count   10002.00    10002.00     10002.00 10002.00 10002.00  10002.00
# mean     4999.67 15690941.34       650.53    38.92     5.01  76479.90
# std      2887.20    71932.88        96.65    10.49     2.89  62396.07
# min         1.00 15565701.00       350.00    18.00     0.00      0.00
# 25%      2499.25 15628537.00       584.00    32.00     3.00      0.00
# 50%      4999.50 15690738.00       652.00    37.00     5.00  97173.29
# 75%      7499.75 15753225.50       718.00    44.00     7.00 127641.42
# max     10000.00 15815690.00       850.00    92.00    10.00 250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10002.00   10002.00        10002.00         10002.00 10002.00
# mean            1.53       0.71            0.52        100094.80     0.20
# std             0.58       0.46            0.50         57510.18     0.40
# ...

# %%
df.tail()
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 9997        9998    15584532        Liu       709.00    France  Female 36.00
# 9998        9999    15682355  Sabbatini       772.00   Germany    Male 42.00
# 9999       10000    15628319     Walker       792.00    France  Female 28.00
# 10006        801    15747542      Perez       605.00   France     Male 52.00
# 10007        901    15642041      Burns       727.00   Germany    male 40.00
#
#        Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9997        7      0.00              1          0               1
# 9998        3  75075.31              2          1               0
# 9999        4 130142.79              1          1               0
# 10006       7      0.00              2          1               1
# 10007       1  93051.64              2          1               0
#
#        EstimatedSalary  Exited
# 9997          42085.58       1
# 9998          92888.52       1
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'male'], dtype=object)

# %%
df['Gender']=df['Gender'].str.replace('m','M')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3788\773543291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']=df['Gender'].str.replace('m','M')

# %%
df['Gender'].unique()
# Out:
# array(['FeMale', 'Male'], dtype=object)

# %%
df['Gender']=df['Gender'].str.replace('FeMale','Female')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3788\2036491342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']=df['Gender'].str.replace('FeMale','Female')

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany', 'France '], dtype=object)

# %%
df['Geography']=df['Geography'].str.replace("France ",'France')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3788\2586044124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Geography']=df['Geography'].str.replace("France ",'France')

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0              1    15634602   Hargrave       619.00    France  Female 42.00
# 1              2    15647311       Hill       608.00     Spain  Female 41.00
# 2              3    15619304       Onio       502.00    France  Female 42.00
# 3              4    15701354       Boni       699.00    France  Female 39.00
# 4              5    15737888   Mitchell       850.00     Spain  Female 43.00
# ...          ...         ...        ...          ...       ...     ...   ...
# 9997        9998    15584532        Liu       709.00    France  Female 36.00
# 9998        9999    15682355  Sabbatini       772.00   Germany    Male 42.00
# 9999       10000    15628319     Walker       792.00    France  Female 28.00
# 10006        801    15747542      Perez       605.00    France    Male 52.00
# 10007        901    15642041      Burns       727.00   Germany    Male 40.00
#
# ...

# %%
df.describe()
# Out:
#        RowNumber  CustomerId  CreditScore      Age   Tenure   Balance  \
# count   10002.00    10002.00     10002.00 10002.00 10002.00  10002.00
# mean     4999.67 15690941.34       650.53    38.92     5.01  76479.90
# std      2887.20    71932.88        96.65    10.49     2.89  62396.07
# min         1.00 15565701.00       350.00    18.00     0.00      0.00
# 25%      2499.25 15628537.00       584.00    32.00     3.00      0.00
# 50%      4999.50 15690738.00       652.00    37.00     5.00  97173.29
# 75%      7499.75 15753225.50       718.00    44.00     7.00 127641.42
# max     10000.00 15815690.00       850.00    92.00    10.00 250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10002.00   10002.00        10002.00         10002.00 10002.00
# mean            1.53       0.71            0.52        100094.80     0.20
# std             0.58       0.46            0.50         57510.18     0.40
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.drop('RowNumber',axis=1,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3788\3300279421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('RowNumber',axis=1,inplace=True)

# %%
df
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0        15634602   Hargrave       619.00    France  Female 42.00       2
# 1        15647311       Hill       608.00     Spain  Female 41.00       1
# 2        15619304       Onio       502.00    France  Female 42.00       8
# 3        15701354       Boni       699.00    France  Female 39.00       1
# 4        15737888   Mitchell       850.00     Spain  Female 43.00       2
# ...           ...        ...          ...       ...     ...   ...     ...
# 9997     15584532        Liu       709.00    France  Female 36.00       7
# 9998     15682355  Sabbatini       772.00   Germany    Male 42.00       3
# 9999     15628319     Walker       792.00    France  Female 28.00       4
# 10000    15747542      Perez       605.00    France    Male 52.00       7
# 10001    15642041      Burns       727.00   Germany    Male 40.00       1
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %% [markdown]
# # Our Data is Clean We may Perform Exploratory Data Analysis
# we aim to understand whether a customer will continue banking with us or decide to leave

# %%
sns.countplot(data=df,x='Geography')
plt.title("Graph Between Customer Count and Geography")
plt.show()

# %%
sns.countplot(data=df,x='Geography',hue='Gender')
plt.title("Graph Between Customer Count,Geography and Gender")
plt.show()

# %% [markdown]
# we observe that the majority of customers are from France, and a significant portion of them are male (not much difference)

# %%
df.dtypes
# Out:
# CustomerId           int64
# Surname             object
# CreditScore        float64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.corr(numeric_only=True,)
# Out:
#                  CustomerId  CreditScore   Age  Tenure  Balance  \
# CustomerId             1.00         0.01  0.01   -0.01    -0.01
# CreditScore            0.01         1.00 -0.00    0.00     0.01
# Age                    0.01        -0.00  1.00   -0.01     0.03
# Tenure                -0.01         0.00 -0.01    1.00    -0.01
# Balance               -0.01         0.01  0.03   -0.01     1.00
# NumOfProducts          0.02         0.01 -0.03    0.01    -0.30
# HasCrCard             -0.01        -0.01 -0.01    0.02    -0.01
# IsActiveMember         0.00         0.03  0.09   -0.03    -0.01
# EstimatedSalary        0.02        -0.00 -0.01    0.01     0.01
# Exited                -0.01        -0.03  0.29   -0.01     0.12
#
#                  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# CustomerId                0.02      -0.01            0.00             0.02
# CreditScore               0.01      -0.01            0.03            -0.00
# ...

# %%
df_corrr=df.drop('CustomerId',axis=1).corr(numeric_only=True)
df_corrr
# Out:
#                  CreditScore   Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# CreditScore             1.00 -0.00    0.00     0.01           0.01      -0.01
# Age                    -0.00  1.00   -0.01     0.03          -0.03      -0.01
# Tenure                  0.00 -0.01    1.00    -0.01           0.01       0.02
# Balance                 0.01  0.03   -0.01     1.00          -0.30      -0.01
# NumOfProducts           0.01 -0.03    0.01    -0.30           1.00       0.00
# HasCrCard              -0.01 -0.01    0.02    -0.01           0.00       1.00
# IsActiveMember          0.03  0.09   -0.03    -0.01           0.01      -0.01
# EstimatedSalary        -0.00 -0.01    0.01     0.01           0.01      -0.01
# Exited                 -0.03  0.29   -0.01     0.12          -0.05      -0.01
#
#                  IsActiveMember  EstimatedSalary  Exited
# CreditScore                0.03            -0.00   -0.03
# Age                        0.09            -0.01    0.29
# ...

# %%
plt.figure(figsize=(9,10))
sns.heatmap(data=df_corrr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# lets focus on the exited and other variables correlations
#
# Age has the strongest +ve corr than other variables , so  old ages peoples has more trend to leave the bank
# IsActiveMember has the strongest -ve corr among other variables so more acive less likely to leave
#
#
# close to zero.
#
# So there is almost no linear association

# %%
# distribution of credit score
sns.histplot(data=df,x='CreditScore',bins=20,kde=True)
# Out:
# <Axes: xlabel='CreditScore', ylabel='Count'>

# %% [markdown]
# CreditScore has Normal Distribution
# most customers have credit scores concentrated approximately between 600 and 700, with the highest concentration around the mid-600s

# %%
sns.histplot(data=df,x='Age',bins=20,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
#  The thin tail points to the right (higher positive numbers), caused by a few high-value outliers

# %%
df['Age'].value_counts()
# Out:
# Age
# 37.00    478
# 38.00    477
# 35.00    474
# 36.00    456
# 34.00    447
#         ...
# 84.00      2
# 82.00      1
# 88.00      1
# 85.00      1
# 83.00      1
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# # lets see in a graph the distibution of age with credit score

# %%
plt.figure(figsize=(9,10))
sns.scatterplot(data=df,x='CreditScore',y='Age')
plt.title('ScatterPlot Between Age and Credit Score')
# Out:
# Text(0.5, 1.0, 'ScatterPlot Between Age and Credit Score')

# %% [markdown]
# NO any relation between the Age and Credit Score
# graph is dispersed, no positive negative pattern (no upward or downward trend)
#
# CreditScore capped at 850
#
# Some age outliers reach above 90( but below 95 )

# %%
df['CreditScore'].value_counts()
# Out:
# CreditScore
# 850.00    233
# 678.00     63
# 655.00     54
# 705.00     53
# 667.00     53
#          ...
# 404.00      1
# 365.00      1
# 382.00      1
# 373.00      1
# 419.00      1
# Name: count, Length: 460, dtype: int64

# %%
sns.countplot(data=df,x='Tenure')
plt.title('CountPlot of Tenure')
# Out:
# Text(0.5, 1.0, 'CountPlot of Tenure')

# %%
df['Exited'].value_counts()*100/len(df['Exited'])
# Out:
# Exited
# 0   79.62
# 1   20.38
# Name: count, dtype: float64

# %%
sns.countplot(data=df,x='Exited')
# Out:
# <Axes: xlabel='Exited', ylabel='count'>

# %% [markdown]
# # Key Observations
# majority are from France
#
# Males and female clients are almost equal(slightly More Male)
#
# CreditScore Outlier at 850 and has Normal Distribution
#
# Age has a slighlty Right skewed distribution cause of the  few high outliers
#
# Distribution of Tenure is aprroximately Uniform with some below 1 year and some having tenure 10 years
#
# 20% of the customers have discontinued their usage of the bank's services
