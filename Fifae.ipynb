# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',200)
import os

# %%
print(os.getcwd())
# Out:
# c:\Users\HP\Desktop\pyy\EDA Assignment\EDa

# %%
data=pd.read_csv('../../fifa2026.csv')

# %%
data
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot          club_name  \
# ...

# %%
data.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'team',
#        'jersey_number', 'position', 'height_cm', 'weight_kg', 'preferred_foot',
#        'club_name', 'market_value_eur', 'match_id', 'match_date', 'stadium',
#        'city', 'opponent_team', 'tournament_stage', 'match_result',
#        'goals_team', 'goals_opponent', 'minutes_played', 'goals', 'assists',
#        'shots', 'shots_on_target', 'expected_goals_xg', 'expected_assists_xa',
#        'key_passes', 'successful_passes', 'total_passes', 'pass_accuracy',
#        'dribbles_attempted', 'successful_dribbles', 'crosses',
#        'successful_crosses', 'tackles', 'interceptions', 'clearances',
#        'blocks', 'aerial_duels_won', 'aerial_duels_lost', 'recoveries',
#        'defensive_actions', 'fouls_committed', 'fouls_suffered',
#        'yellow_cards', 'red_cards', 'offsides', 'saves', 'save_percentage',
#        'punches', 'clean_sheet', 'goals_conceded', 'penalty_saves',
# ...

# %%
df=data[['player_id', 'player_name', 'age', 'nationality', 
         #'team',
       #'jersey_number',
        'position', 'height_cm', 'weight_kg', 
        'preferred_foot',
       #'club_name', 
       'market_value_eur', 
       #'match_id', 'match_date',
        # 'stadium',
       #'city', 'opponent_team', 'tournament_stage', 
       #'match_result',
      # 'goals_team', 'goals_opponent',
       'minutes_played', 
      'goals', 'assists',
       'shots', 'shots_on_target', 
       #'expected_goals_xg', 'expected_assists_xa',
       #'key_passes', 
       'successful_passes', 'total_passes', 
       #'pass_accuracy',

       #'dribbles_attempted', 'successful_dribbles', 'crosses',
       #'successful_crosses', 'tackles', 'interceptions', 'clearances',
       #'blocks', 'aerial_duels_won', 'aerial_duels_lost', 'recoveries',
       # 'defensive_actions', 'fouls_committed', 'fouls_suffered',
       # 'yellow_cards', 'red_cards', 'offsides', 'saves', 'save_percentage',
       # 'punches', 'clean_sheet', 'goals_conceded', 'penalty_saves',
       # 'distance_covered_km', 'sprint_distance_km', 'top_speed_kmh',
       # 'accelerations', 'decelerations', 'stamina_score', 'player_rating',
       # 'performance_score', 'offensive_contribution', 'defensive_contribution',
       # 'possession_impact', 'pressure_resistance', 'creativity_score',
       # 'consistency_score', 'clutch_performance_score',
        #'total_goals_tournament', 'total_assists_tournament',
      # 'total_minutes_tournament', 
       #'player_of_match_awards',
       # 'tournament_rating'
        ]].copy()

# %%
df  # per match level statistics
# Out:
#       player_id       player_name  age nationality    position  height_cm  \
# 0        P00055        Rodri Fati   26     Spanish  Goalkeeper        195
# 1        P00070   Ansu Le Normand   19     Spanish  Midfielder        178
# 2        P00066        Gavi Ramos   18     Spanish  Midfielder        177
# 3        P00073     Pedro Cubarsi   20     Spanish     Forward        182
# 4        P00059  Alvaro Oyarzabal   23     Spanish    Defender        191
# ...         ...               ...  ...         ...         ...        ...
# 54595    P00996       Amir Younis   28       Iraqi    Defender        177
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi  Midfielder        176
# 54597    P01008     Ahmed Hussein   26       Iraqi  Midfielder        173
# 54598    P00991     Ibrahim Mhawi   30       Iraqi  Goalkeeper        190
# 54599    P00989  Mohannad Hussein   27       Iraqi  Goalkeeper        187
#
#        weight_kg preferred_foot  market_value_eur  minutes_played  goals  \
# ...

# %%
df.shape
# Out:
# (54600, 16)

# %%
df.describe()
# Out:
#                 age     height_cm     weight_kg  market_value_eur  \
# count  54600.000000  54600.000000  54600.000000      5.460000e+04
# mean      26.296484    181.654341     75.754853      2.008445e+07
# std        4.067519      6.277792      3.951481      2.718866e+07
# min       17.000000    163.000000     65.000000      5.288220e+05
# 25%       23.000000    177.000000     73.000000      4.444778e+06
# 50%       26.000000    182.000000     76.000000      1.027111e+07
# 75%       29.000000    186.000000     78.000000      2.342013e+07
# max       39.000000    200.000000     87.000000      2.000000e+08
#
#        minutes_played         goals       assists         shots  \
# count    54600.000000  54600.000000  54600.000000  54600.000000
# mean        36.199817      0.055385      0.052363      0.447051
# std         36.419755      0.251900      0.239021      0.947155
# min          0.000000      0.000000      0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'position',
#        'height_cm', 'weight_kg', 'preferred_foot', 'market_value_eur',
#        'minutes_played', 'goals', 'assists', 'shots', 'shots_on_target',
#        'successful_passes', 'total_passes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# player_id            object
# player_name          object
# age                   int64
# nationality          object
# position             object
# height_cm             int64
# weight_kg             int64
# preferred_foot       object
# market_value_eur      int64
# minutes_played        int64
# goals                 int64
# assists               int64
# shots                 int64
# shots_on_target       int64
# successful_passes     int64
# total_passes          int64
# dtype: object

# %%
df.isna().sum()
# Out:
# player_id            0
# player_name          0
# age                  0
# nationality          0
# position             0
# height_cm            0
# weight_kg            0
# preferred_foot       0
# market_value_eur     0
# minutes_played       0
# goals                0
# assists              0
# shots                0
# shots_on_target      0
# successful_passes    0
# total_passes         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(21807)

# %%
df.query('player_name == "Ivan Kramaric"')  # so in this data set we have player by matches so each player occurs multiple times cause every occurence is differrnt match
# Out:
#       player_id    player_name  age nationality    position  height_cm  \
# 832      P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 1897     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 4081     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 4288     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 4886     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 7020     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 7460     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 8034     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 8606     P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 10762    P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 15702    P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# 15780    P00211  Ivan Kramaric   29    Croatian  Goalkeeper        188
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# player_id            object
# player_name          object
# age                   int64
# nationality          object
# position             object
# height_cm             int64
# weight_kg             int64
# preferred_foot       object
# market_value_eur      int64
# minutes_played        int64
# goals                 int64
# assists               int64
# shots                 int64
# shots_on_target       int64
# successful_passes     int64
# total_passes          int64
# dtype: object

# %%
df.head()
# Out:
#   player_id       player_name  age nationality    position  height_cm  \
# 0    P00055        Rodri Fati   26     Spanish  Goalkeeper        195
# 1    P00070   Ansu Le Normand   19     Spanish  Midfielder        178
# 2    P00066        Gavi Ramos   18     Spanish  Midfielder        177
# 3    P00073     Pedro Cubarsi   20     Spanish     Forward        182
# 4    P00059  Alvaro Oyarzabal   23     Spanish    Defender        191
#
#    weight_kg preferred_foot  market_value_eur  minutes_played  goals  assists  \
# 0         75           Left           4384884              72      0        0
# 1         75          Right           4918927              90      0        0
# 2         72           Left         125015698              73      1        0
# 3         74          Right          11805512              80      1        1
# 4         81           Left          13325174              79      0        0
#
#    shots  shots_on_target  successful_passes  total_passes
# ...

# %%
df["nationality"].value_counts()
# Out:
# nationality
# Qatari           1022
# Jamaican          915
# Moroccan          851
# Italian           832
# Dutch             831
# Saudi             806
# Belgian           782
# Turkish           768
# Scottish          761
# Croatian          758
# Peruvian          754
# Canadian          748
# Tunisian          742
# Ecuadorian        741
# Australian        738
# Panamanian        737
# Costa Rican       716
# Uruguayan         707
# Colombian         705
# Ghanaian          703
# Spanish           700
# Egyptian          696
# Brazilian         694
# Cameroonian       690
# English           688
# Uzbek             677
# Portuguese        670
# Danish            662
# Serbian           656
# Algerian          641
# Iraqi             638
# Nigerian          628
# Mexican           621
# Polish            617
# Ukrainian         602
# Senegalese        600
# American          600
# Iranian           595
# Japanese          575
# Chilean           575
# Swedish           569
# ...

# %%
df['player_id'].sort_values() # sorting only player id series
# Out:
# 31798    P00001
# 1246     P00001
# 17446    P00001
# 10790    P00001
# 36400    P00001
#           ...
# 1438     P01248
# 32479    P01248
# 33731    P01248
# 45607    P01248
# 34198    P01248
# Name: player_id, Length: 32793, dtype: object

# %%
df.sort_values('player_id')  # sortnt he entire df
# our rows consists of each player match  in different matches so only the match stats is different as you can see the other sats are quite the same
# Out:
#       player_id       player_name  age    nationality    position  height_cm  \
# 31798    P00001  Kylian Griezmann   24         French  Goalkeeper        191
# 1246     P00001  Kylian Griezmann   24         French  Goalkeeper        191
# 17446    P00001  Kylian Griezmann   24         French  Goalkeeper        191
# 10790    P00001  Kylian Griezmann   24         French  Goalkeeper        191
# 36400    P00001  Kylian Griezmann   24         French  Goalkeeper        191
# ...         ...               ...  ...            ...         ...        ...
# 1438     P01248     Mothobi Mvala   29  South African     Forward        183
# 32479    P01248     Mothobi Mvala   29  South African     Forward        183
# 33731    P01248     Mothobi Mvala   29  South African     Forward        183
# 45607    P01248     Mothobi Mvala   29  South African     Forward        183
# 34198    P01248     Mothobi Mvala   29  South African     Forward        183
#
# ...

# %% [markdown]
# df['Goals]

# %%
df['Goals_Contribution']=df['goals']+df['assists']

# %%
df
# Out:
#       player_id        player_name  age nationality    position  height_cm  \
# 0        P00055         Rodri Fati   26     Spanish  Goalkeeper        195
# 1        P00070    Ansu Le Normand   19     Spanish  Midfielder        178
# 2        P00066         Gavi Ramos   18     Spanish  Midfielder        177
# 3        P00073      Pedro Cubarsi   20     Spanish     Forward        182
# 4        P00059   Alvaro Oyarzabal   23     Spanish    Defender        191
# ...         ...                ...  ...         ...         ...        ...
# 54583    P01011      Ibrahim Sadiq   32       Iraqi     Forward        175
# 54584    P00995        Ali Mohanad   27       Iraqi    Defender        188
# 54585    P00999       Ahmed Moutan   26       Iraqi    Defender        187
# 54586    P01010   Aymen Al-Khafaji   26       Iraqi     Forward        184
# 54587    P01001  Mohannad Al-Saadi   29       Iraqi  Midfielder        175
#
# ...

# %%
#df['Shots_Accuracy']=( df['shots_on_target']/df['shots'] *100)  NOTE but we can have shots on target and shots 0 so it may cause problem while dividing

# %%
df['Shots_Accuracy']=np.where(df['shots']>0 , df['shots_on_target']/df['shots'] *100,0) # we leep true conditin np.where(true,do this,else do this)
#np.where works like an if else but here we are working on pandas series
# if shots >0 , calulate the shot accuracy or else return 0

# %%
df['Shots_Accuracy'].value_counts()
# Out:
# Shots_Accuracy
# 0.000000     30477
# 33.333333     1330
# 25.000000      630
# 20.000000      137
# 40.000000      126
# 28.571429       33
# 16.666667       24
# 42.857143       20
# 37.500000       11
# 44.444444        2
# 27.272727        1
# 45.454545        1
# 30.000000        1
# Name: count, dtype: int64

# %%
df
# Out:
#       player_id        player_name  age nationality    position  height_cm  \
# 0        P00055         Rodri Fati   26     Spanish  Goalkeeper        195
# 1        P00070    Ansu Le Normand   19     Spanish  Midfielder        178
# 2        P00066         Gavi Ramos   18     Spanish  Midfielder        177
# 3        P00073      Pedro Cubarsi   20     Spanish     Forward        182
# 4        P00059   Alvaro Oyarzabal   23     Spanish    Defender        191
# ...         ...                ...  ...         ...         ...        ...
# 54583    P01011      Ibrahim Sadiq   32       Iraqi     Forward        175
# 54584    P00995        Ali Mohanad   27       Iraqi    Defender        188
# 54585    P00999       Ahmed Moutan   26       Iraqi    Defender        187
# 54586    P01010   Aymen Al-Khafaji   26       Iraqi     Forward        184
# 54587    P01001  Mohannad Al-Saadi   29       Iraqi  Midfielder        175
#
# ...

# %%
df['total_passes'].value_counts()
# Out:
# total_passes
# 0     1330
# 23     684
# 20     682
# 22     680
# 25     668
#       ...
# 95      21
# 97      20
# 98      18
# 94      14
# 99      12
# Name: count, Length: 101, dtype: int64

# %%
df['Passing_Accuracy']=np.where(df['total_passes'] >0,df['successful_passes']/df['total_passes'] *100 ,0)

# %%
df
# Out:
#       player_id        player_name  age nationality    position  height_cm  \
# 0        P00055         Rodri Fati   26     Spanish  Goalkeeper        195
# 1        P00070    Ansu Le Normand   19     Spanish  Midfielder        178
# 2        P00066         Gavi Ramos   18     Spanish  Midfielder        177
# 3        P00073      Pedro Cubarsi   20     Spanish     Forward        182
# 4        P00059   Alvaro Oyarzabal   23     Spanish    Defender        191
# ...         ...                ...  ...         ...         ...        ...
# 54583    P01011      Ibrahim Sadiq   32       Iraqi     Forward        175
# 54584    P00995        Ali Mohanad   27       Iraqi    Defender        188
# 54585    P00999       Ahmed Moutan   26       Iraqi    Defender        187
# 54586    P01010   Aymen Al-Khafaji   26       Iraqi     Forward        184
# 54587    P01001  Mohannad Al-Saadi   29       Iraqi  Midfielder        175
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'position',
#        'height_cm', 'weight_kg', 'preferred_foot', 'market_value_eur',
#        'minutes_played', 'goals', 'assists', 'shots', 'shots_on_target',
#        'successful_passes', 'total_passes', 'Goals_Contribution',
#        'Shots_Accuracy', 'Passing_Accuracy'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age     height_cm     weight_kg  market_value_eur  \
# count  32793.000000  32793.000000  32793.000000      3.279300e+04
# mean      26.182844    181.261946     75.612021      2.051097e+07
# std        4.017442      6.158866      3.923941      2.765547e+07
# min       17.000000    163.000000     65.000000      5.288220e+05
# 25%       23.000000    177.000000     73.000000      4.603871e+06
# 50%       26.000000    182.000000     76.000000      1.044460e+07
# 75%       29.000000    185.000000     78.000000      2.383264e+07
# max       39.000000    200.000000     87.000000      2.000000e+08
#
#        minutes_played         goals       assists         shots  \
# count    32793.000000  32793.000000  32793.000000  32793.000000
# mean        60.224438      0.092215      0.087122      0.744122
# std         27.574628      0.319773      0.303377      1.128026
# min          0.000000      0.000000      0.000000      0.000000
# ...

# %%
sns.histplot(data=df,x='age',binwidth=1)
plt.title('Distribution of Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %%
df['age'].describe()
# Out:
# count    32793.000000
# mean        26.182844
# std          4.017442
# min         17.000000
# 25%         23.000000
# 50%         26.000000
# 75%         29.000000
# max         39.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(16,19))
sns.histplot(data=df,y='nationality')
plt.title('Distribution of Nationality')
# Out:
# Text(0.5, 1.0, 'Distribution of Nationality')

# %%
df['nationality'].unique()
# Out:
# array(['Spanish', 'South African', 'Peruvian', 'Dutch', 'Moroccan',
#        'Senegalese', 'Algerian', 'Italian', 'Brazilian', 'Scottish',
#        'Danish', 'Ghanaian', 'Iraqi', 'Nigerian', 'Panamanian',
#        'Cameroonian', 'Colombian', 'Swedish', 'Polish', 'Jamaican',
#        'Croatian', 'Ukrainian', 'Uzbek', 'Ecuadorian', 'English',
#        'Australian', 'French', 'Saudi', 'Chilean', 'Canadian', 'Egyptian',
#        'South Korean', 'Belgian', 'Swiss', 'Iranian', 'Japanese',
#        'German', 'Argentine', 'Turkish', 'Qatari', 'Costa Rican',
#        'Portuguese', 'Uruguayan', 'Mexican', 'Serbian', 'American',
#        'Tunisian', 'Austrian'], dtype=object)

# %%
df['position'].unique()
# Out:
# array(['Goalkeeper', 'Midfielder', 'Forward', 'Defender'], dtype=object)

# %%
sns.countplot(data=df,x='position')
plt.title('Distribution by Position')
# Out:
# Text(0.5, 1.0, 'Distribution by Position')

# %%
df.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'position',
#        'height_cm', 'weight_kg', 'preferred_foot', 'market_value_eur',
#        'minutes_played', 'goals', 'assists', 'shots', 'shots_on_target',
#        'successful_passes', 'total_passes', 'Goals_Contribution',
#        'Shots_Accuracy', 'Passing_Accuracy'],
#       dtype='object')

# %%
sns.scatterplot(
    data=df,
    x="height_cm",
    y="weight_kg"
)
# Out:
# <Axes: xlabel='height_cm', ylabel='weight_kg'>

# %%
df_pos=df.groupby('position')[['height_cm','weight_kg']].mean().reset_index()
df_pos
# Out:
#      position   height_cm  weight_kg
# 0    Defender  183.563797  76.425199
# 1     Forward  178.582372  74.160732
# 2  Goalkeeper  189.211640  78.640653
# 3  Midfielder  179.001409  75.144682

# %%
sns.scatterplot(data=df,x='weight_kg',y='height_cm',hue='position')
# Out:
# <Axes: xlabel='weight_kg', ylabel='height_cm'>

# %%
df_corr=df.corr(numeric_only=True)
df_corr
# Out:
#                          age  height_cm  weight_kg  market_value_eur  \
# age                 1.000000   0.095928   0.069094         -0.061245
# height_cm           0.095928   1.000000   0.622979         -0.097812
# weight_kg           0.069094   0.622979   1.000000         -0.065233
# market_value_eur   -0.061245  -0.097812  -0.065233          1.000000
# minutes_played      0.011243   0.045575   0.032229          0.005348
# goals              -0.040376  -0.090708  -0.069477          0.115978
# assists            -0.028308  -0.072847  -0.041949          0.101257
# shots              -0.082485  -0.174341  -0.122369          0.236436
# shots_on_target    -0.048088  -0.091214  -0.071443          0.185727
# successful_passes  -0.043566  -0.028846   0.009684          0.314276
# total_passes       -0.040111  -0.017778   0.012945          0.323650
# Goals_Contribution -0.047273  -0.112375  -0.076835          0.149095
# Shots_Accuracy     -0.048197  -0.094613  -0.073239          0.173112
# ...

# %%
plt.figure(figsize=(15,17))
sns.heatmap(data=df_corr,annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#       player_id        player_name  age nationality    position  height_cm  \
# 0        P00055         Rodri Fati   26     Spanish  Goalkeeper        195
# 1        P00070    Ansu Le Normand   19     Spanish  Midfielder        178
# 2        P00066         Gavi Ramos   18     Spanish  Midfielder        177
# 3        P00073      Pedro Cubarsi   20     Spanish     Forward        182
# 4        P00059   Alvaro Oyarzabal   23     Spanish    Defender        191
# ...         ...                ...  ...         ...         ...        ...
# 54583    P01011      Ibrahim Sadiq   32       Iraqi     Forward        175
# 54584    P00995        Ali Mohanad   27       Iraqi    Defender        188
# 54585    P00999       Ahmed Moutan   26       Iraqi    Defender        187
# 54586    P01010   Aymen Al-Khafaji   26       Iraqi     Forward        184
# 54587    P01001  Mohannad Al-Saadi   29       Iraqi  Midfielder        175
#
# ...

# %%
df['age'].describe()
# Out:
# count    32793.000000
# mean        26.182844
# std          4.017442
# min         17.000000
# 25%         23.000000
# 50%         26.000000
# 75%         29.000000
# max         39.000000
# Name: age, dtype: float64

# %%
df["age_group"] = pd.cut(
    df["age"],
    bins=[16,21,28,35,50],
    labels=["Young","Prime","Experienced","Veteran"]
)
df
# Out:
#       player_id        player_name  age nationality    position  height_cm  \
# 0        P00055         Rodri Fati   26     Spanish  Goalkeeper        195
# 1        P00070    Ansu Le Normand   19     Spanish  Midfielder        178
# 2        P00066         Gavi Ramos   18     Spanish  Midfielder        177
# 3        P00073      Pedro Cubarsi   20     Spanish     Forward        182
# 4        P00059   Alvaro Oyarzabal   23     Spanish    Defender        191
# ...         ...                ...  ...         ...         ...        ...
# 54583    P01011      Ibrahim Sadiq   32       Iraqi     Forward        175
# 54584    P00995        Ali Mohanad   27       Iraqi    Defender        188
# 54585    P00999       Ahmed Moutan   26       Iraqi    Defender        187
# 54586    P01010   Aymen Al-Khafaji   26       Iraqi     Forward        184
# 54587    P01001  Mohannad Al-Saadi   29       Iraqi  Midfielder        175
#
# ...

# %%
df.groupby('age_group')['Goals_Contribution'].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22236\3380290725.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['Goals_Contribution'].mean()
# age_group
# Young          0.214585
# Prime          0.184318
# Experienced    0.156185
# Veteran        0.072000
# Name: Goals_Contribution, dtype: float64

# %%
sns.barplot(data=df,x='age_group',y='Goals_Contribution')
# Out:
# <Axes: xlabel='age_group', ylabel='Goals_Contribution'>

# %% [markdown]
# Players Summary

# %%
df.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'position',
#        'height_cm', 'weight_kg', 'preferred_foot', 'market_value_eur',
#        'minutes_played', 'goals', 'assists', 'shots', 'shots_on_target',
#        'successful_passes', 'total_passes', 'Goals_Contribution',
#        'Shots_Accuracy', 'Passing_Accuracy', 'age_group'],
#       dtype='object')

# %%
player_summary = df.groupby("player_id").agg({
    'player_name': "first",
    'age': "first",
    'nationality': "first",
    'position': "first",
    'height_cm': "first",
    'weight_kg': "first",
    'preferred_foot': "first",
    'market_value_eur': "first",

    'minutes_played': "sum",
    'goals': "sum",
    'assists': "sum",
    'shots': "sum",
    'shots_on_target': "sum",
    'successful_passes': "sum",
    'total_passes': "sum",

    'Goals_Contribution': "sum",
    'age_group': "first"
}).reset_index()

# %%
player_summary # better cleam summary
# Out:
#      player_id         player_name  age    nationality    position  height_cm  \
# 0       P00001    Kylian Griezmann   24         French  Goalkeeper        191
# 1       P00002  Antoine Tchouameni   29         French  Goalkeeper        190
# 2       P00003   Ousmane Hernandez   24         French  Goalkeeper        191
# 3       P00004    Kylian Camavinga   27         French    Defender        183
# 4       P00005      Antoine Kounde   24         French    Defender        188
# ...        ...                 ...  ...            ...         ...        ...
# 1243    P01244         Themba Xoki   24  South African     Forward        178
# 1244    P01245         Lyle Mbatha   24  South African     Forward        171
# 1245    P01246        Teboho Zwane   26  South African     Forward        169
# 1246    P01247      Ronwen Mokoena   23  South African     Forward        169
# 1247    P01248       Mothobi Mvala   29  South African     Forward        183
#
# ...
